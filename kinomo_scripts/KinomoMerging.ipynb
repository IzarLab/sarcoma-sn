# %%
import pandas as pd
import seaborn as sns


first_best_samples = ["Sarcoma167GEX/Sarcoma167GEX_KINOMO_nmf_rank_4_W.csv",
                     "Sarcoma322GEX/Sarcoma322GEX_KINOMO_nmf_rank_3_W.csv",
                     "Sarcoma559GEX/Sarcoma559GEX_KINOMO_nmf_rank_3_W.csv",
                     "Sarcoma708GEX/Sarcoma708GEX_KINOMO_nmf_rank_4_W.csv",
                     "SarcomaS408GEX/SarcomaS408GEX_KINOMO_nmf_rank_3_W.csv",
                     "SarcomaS410GEX/SarcomaS410GEX_KINOMO_nmf_rank_3_W.csv",
                     "SarcomaS914GEX/SarcomaS914GEX_KINOMO_nmf_rank_3_W.csv",
                     "SarcomaS956GEX/SarcomaS956GEX_KINOMO_nmf_rank_5_W.csv"]


first_best_samples_H_matrix = ["Sarcoma167GEX/Sarcoma167GEX_KINOMO_nmf_rank_4_H.csv",
                     "Sarcoma322GEX/Sarcoma322GEX_KINOMO_nmf_rank_3_H.csv",
                     "Sarcoma559GEX/Sarcoma559GEX_KINOMO_nmf_rank_3_H.csv",
                     "Sarcoma708GEX/Sarcoma708GEX_KINOMO_nmf_rank_4_H.csv",
                     "SarcomaS408GEX/SarcomaS408GEX_KINOMO_nmf_rank_3_H.csv",
                     "SarcomaS410GEX/SarcomaS410GEX_KINOMO_nmf_rank_3_H.csv",
                     "SarcomaS914GEX/SarcomaS914GEX_KINOMO_nmf_rank_3_H.csv",
                     "SarcomaS956GEX/SarcomaS956GEX_KINOMO_nmf_rank_5_H.csv"]



top_100_samples = ["Sarcoma167GEX/Sarcoma167GEX_KINOMO_nmf_rank_4_top100_W.csv",
                     "Sarcoma322GEX/Sarcoma322GEX_KINOMO_nmf_rank_3_top100_W.csv",
                     "Sarcoma559GEX/Sarcoma559GEX_KINOMO_nmf_rank_3_top100_W.csv",
                     "Sarcoma708GEX/Sarcoma708GEX_KINOMO_nmf_rank_4_top100_W.csv",
                     "SarcomaS408GEX/SarcomaS408GEX_KINOMO_nmf_rank_3_top100_W.csv",
                     "SarcomaS410GEX/SarcomaS410GEX_KINOMO_nmf_rank_3_top100_W.csv",
                     "SarcomaS914GEX/SarcomaS914GEX_KINOMO_nmf_rank_3_top100_W.csv",
                     "SarcomaS956GEX/SarcomaS956GEX_KINOMO_nmf_rank_5_top100_W.csv"]


second_best_samples = ["Sarcoma167GEX/Sarcoma167GEX_KINOMO_nmf_rank_5_W.csv",
                     "Sarcoma322GEX/Sarcoma322GEX_KINOMO_nmf_rank_5_W.csv",
                     "Sarcoma559GEX/Sarcoma559GEX_KINOMO_nmf_rank_6_W.csv",
                     "Sarcoma708GEX/Sarcoma708GEX_KINOMO_nmf_rank_6_W.csv",
                     "SarcomaS408GEX/SarcomaS408GEX_KINOMO_nmf_rank_5_W.csv",
                     "SarcomaS410GEX/SarcomaS410GEX_KINOMO_nmf_rank_5_W.csv",
                     "SarcomaS914GEX/SarcomaS914GEX_KINOMO_nmf_rank_5_W.csv",
                     "SarcomaS956GEX/SarcomaS956GEX_KINOMO_nmf_rank_8_W.csv"]


second_top_100_samples = ["Sarcoma167GEX/Sarcoma167GEX_KINOMO_nmf_rank_5_top100_W.csv",
                     "Sarcoma322GEX/Sarcoma322GEX_KINOMO_nmf_rank_5_top100_W.csv",
                     "Sarcoma559GEX/Sarcoma559GEX_KINOMO_nmf_rank_6_top100_W.csv",
                     "Sarcoma708GEX/Sarcoma708GEX_KINOMO_nmf_rank_6_top100_W.csv",
                     "SarcomaS408GEX/SarcomaS408GEX_KINOMO_nmf_rank_5_top100_W.csv",
                     "SarcomaS410GEX/SarcomaS410GEX_KINOMO_nmf_rank_5_top100_W.csv",
                     "SarcomaS914GEX/SarcomaS914GEX_KINOMO_nmf_rank_5_top100_W.csv",
                     "SarcomaS956GEX/SarcomaS956GEX_KINOMO_nmf_rank_8_top100_W.csv"]


suffixes = ["_167", "_322", "_559", "_708", "_S408", "_S410", "_S914", "_S956"]
pre_post_row = ["pre1","pre2","NA", "NA","NA", "post1", "post2", "NA"]
intimal_ups = ["intimal", "UPS", "intimal", "UPS", "UPS", "intimal", "UPS", "UPS"]
op_pre_post = ["pre_op", "post_op", "pre_op", "pre_op", "post_tx",
               "post_op", "pre_op", "post_op"]

dataframes= []
for i,x in enumerate(first_best_samples):
    temp_df = pd.read_csv(x).set_index("Unnamed: 0")
    
    ranks = pd.read_csv(top_100_samples[i]).set_index("Unnamed: 0")
    dataframes.append(temp_df[temp_df.index.isin(list(ranks.to_numpy().flatten()))])
    dataframes
    
    
second_dataframes= []
for i,x in enumerate(second_best_samples):
    temp_df = pd.read_csv(x).set_index("Unnamed: 0")
    
    ranks = pd.read_csv(second_top_100_samples[i]).set_index("Unnamed: 0")
    second_dataframes.append(temp_df[temp_df.index.isin(list(ranks.to_numpy().flatten()))])
    second_dataframes

# %%
pd.read_csv(second_best_samples[i]).set_index("Unnamed: 0")
# Out:
#                       V1            V2            V3            V4  \
# Unnamed: 0
# AL627309.1  2.612051e-01  9.049418e-02  1.200097e-01  2.086958e-06
# AL627309.2  2.220446e-16  2.220446e-16  2.220446e-16  2.220446e-16
# AL627309.5  1.055412e+00  3.947711e-01  2.220446e-16  1.991807e+00
# AL732372.1  2.220446e-16  2.220446e-16  2.220446e-16  8.797549e-02
# AL669831.2  2.220446e-16  2.220446e-16  2.220446e-16  2.220446e-16
# ...                  ...           ...           ...           ...
# AC004556.3  2.220446e-16  2.220446e-16  2.220446e-16  2.220446e-16
# AC136612.1  2.220446e-16  1.793673e-01  2.220446e-16  2.220446e-16
# AC136616.1  2.220446e-16  1.905391e+00  2.220446e-16  3.415286e-01
# AC007325.4  2.220446e-16  1.569813e-01  2.220446e-16  8.822893e-01
# AC007325.2  2.220446e-16  8.257782e-01  2.220446e-16  2.802151e-01
#
#                       V5            V6            V7            V8
# Unnamed: 0
# AL627309.1  2.220446e-16  2.220446e-16  4.093627e-01  7.278269e-01
# ...

# %%
second_dataframes[0]
# Out:
#                    V1          V2            V3            V4            V5
# Unnamed: 0
# EIF4G3      41.685732   44.687037  8.926315e+01  2.515025e+01  2.946414e+00
# MACF1       37.198196   45.042544  6.746529e+01  5.407153e+01  1.390836e+01
# SMAP2        6.769199   12.429771  8.956691e+01  3.936887e+01  5.216878e+00
# NFIA        41.357645  108.296960  4.942918e+01  1.801069e+01  3.488913e+01
# SRSF11      41.949639   72.257101  4.882878e+01  3.641671e+01  1.539422e-06
# ...               ...         ...           ...           ...           ...
# TNRC6B      26.084742   64.840046  4.173990e+01  4.761869e+01  1.347962e+01
# MRTFA       40.856248   76.187860  4.351114e+01  1.091499e+00  9.605939e+00
# SAT1         3.943875    3.397133  1.128149e+02  1.293212e+00  2.220446e-16
# IL1RAPL1    46.664125  103.569755  2.220446e-16  2.220446e-16  1.117970e+01
# CASK        23.196578   39.582861  1.421898e+01  5.369368e+01  3.866015e-03
#
# [379 rows x 5 columns]

# %%
list(ranks.to_numpy().flatten())
# Out:
# ['MKI67',
#  'TENM3',
#  'FP236383.3',
#  'COL25A1',
#  'BRIP1',
#  'FP236383.3',
#  'LSAMP',
#  'TENM3',
#  'CENPF',
#  'MALAT1',
#  'MALAT1',
#  'ADGRL3',
#  'MIR924HG',
#  'EEF1A1',
#  'NRXN3',
#  'FP236383.3',
#  'FP236383.3',
#  'ROBO2',
#  'NEAT1',
#  'LSAMP',
#  'LRMDA',
#  'SFRP1',
#  'TENM3',
#  'MALAT1',
#  'TOP2A',
#  'RBMS3',
#  'DOCK4',
#  'LIMCH1',
#  'FP236383.3',
#  'VIM',
#  'LRMDA',
#  'LRMDA',
#  'ASPM',
#  'ITGA8',
#  'MACF1',
#  'RBMS3',
#  'MALAT1',
#  'EEF2',
#  'FP236383.3',
#  'AFF3',
#  'TENM3',
#  'LRMDA',
#  'PRKCH',
#  'MALAT1',
#  'POLA1',
#  'IGF2',
#  'PBX3',
#  'LRFN5',
#  'SFRP1',
#  'FP236383.3',
#  'XIST',
#  'FP236383.3',
#  'PRIM2',
#  'COL1A2',
#  'MALAT1',
#  'RBMS3',
#  'FP671120.4',
#  'MBNL1',
#  'FP671120.4',
#  'TSHZ2',
#  'CENPP',
#  'H19',
#  'AC092691.1',
#  'FHIT',
#  'MALAT1',
#  'ADGRL3',
#  'PITPNC1',
#  'TENM3',
#  'SYNE2',
#  'FP671120.4',
#  'RBMS3',
#  'AUTS2',
#  'NTRK2',
#  'LRFN5',
#  'COL4A1',
#  'PTPRG',
#  'LSAMP',
# ...

# %%
dataframes[0][dataframes[0].index.isin(list(ranks.to_numpy().flatten()))]
# Out:
#                    V1            V2            V3          V4
# Unnamed: 0
# MACF1       35.385284  7.813065e+01  5.861457e+01   57.944826
# SMAP2        7.632060  1.066168e+02  4.502478e+01   15.075881
# NFIA        40.152119  6.114097e+01  1.872787e+01  138.503966
# DPYD        18.519733  1.831224e+02  6.904908e+01   85.567909
# NOTCH2      39.371951  2.198250e+01  2.220446e-16   77.373499
# ...               ...           ...           ...         ...
# FP671120.4  55.543743  3.170611e+00  4.165609e-01   52.986004
# FP236383.3  84.097339  1.886442e+01  1.305002e+01   86.583848
# APP         49.861687  4.852984e+01  2.220446e-16   48.655910
# RBFOX2      38.005348  2.220446e-16  2.220446e-16   91.673205
# SAT1         2.088469  1.397470e+02  1.500839e-15    3.572432
#
# [123 rows x 4 columns]

# %%
dataframes[0]
# Out:
#                    V1            V2            V3          V4
# Unnamed: 0
# EIF4G3      31.318242  1.041336e+02  3.177341e+01   56.216788
# MACF1       35.385284  7.813065e+01  5.861457e+01   57.944826
# SMAP2        7.632060  1.066168e+02  4.502478e+01   15.075881
# NFIA        40.152119  6.114097e+01  1.872787e+01  138.503966
# PDE4B       18.750223  9.805421e+01  2.915778e+01   69.255123
# ...               ...           ...           ...         ...
# MRTFA       35.081387  5.167526e+01  3.736569e-01   93.032574
# SAT1         2.088469  1.397470e+02  1.500839e-15    3.572432
# IL1RAPL1    16.507108  2.220446e-16  2.220446e-16  137.091157
# CASK        14.804677  1.259111e+01  5.560503e+01   49.708916
# AL008633.1  17.097585  2.220446e-16  2.220446e-16   94.331347
#
# [323 rows x 4 columns]

# %%
dataframes[1]
# Out:
#                       V1            V2          V3
# Unnamed: 0
# KAZN        2.002570e+00  1.690980e-01  106.525740
# HMGN2       1.204062e+02  1.968306e+00   17.557425
# MACF1       5.342285e+01  4.851083e+01   47.692231
# FAF1        2.220446e-16  3.546406e+01   93.615578
# NFIA        5.743982e+01  6.901787e+00  101.480217
# ...                  ...           ...         ...
# TIMP1       8.996652e+01  2.220446e-16   17.060878
# FTX         2.220446e-16  4.950671e+01  101.961307
# AC233296.1  2.220446e-16  2.220446e-16   83.682564
# DIAPH2      2.220446e-16  3.228968e+01  105.037329
# FLNA        9.635540e+01  1.139178e+01    5.376069
#
# [264 rows x 3 columns]

# %%
main_df = dataframes[0]
main_df = main_df.add_suffix(suffixes[0])
pre_post_labels = [pre_post_row[0]]* len(main_df.columns)

intimal_ups_labels = [intimal_ups[0]]* len(main_df.columns)
op_pre_post_labels = [op_pre_post[0]]* len(main_df.columns)

for i,x in enumerate(dataframes[1:]):
    print(i)
    main_df
    
    main_df = pd.merge(
         main_df, x.add_suffix(suffixes[i+1]), how="outer", on=["Unnamed: 0"]
    )
    pre_post_labels.extend([pre_post_row[i+1] ]* len(x.columns))
    intimal_ups_labels.extend([intimal_ups[i+1] ]* len(x.columns))
    op_pre_post_labels.extend([op_pre_post[i+1] ]* len(x.columns))

#main_df = main_df.fillna(0)
corr_df = main_df.corr(method='pearson')



main_df_second = second_dataframes[0]
main_df_second = main_df_second.add_suffix(suffixes[0])
pre_post_labels_second = [pre_post_row[0]]* len(main_df_second.columns)
intimal_ups_labels_second = [intimal_ups[0]]* len(main_df.columns)

for i,x in enumerate(second_dataframes[1:]):   
    main_df_second = pd.merge(
         main_df_second, x.add_suffix(suffixes[i+1]), how="outer", on=["Unnamed: 0"]
    )
    pre_post_labels_second.extend([pre_post_row[i+1] ]* len(x.columns))
    intimal_ups_labels_second.extend([intimal_ups[i+1] ]* len(x.columns))

#main_df = main_df.fillna(0)
corr_df_second = main_df_second.corr(method='pearson')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
main_df_second
# Out:
#                V1_167      V2_167     V3_167     V4_167     V5_167     V1_322  \
# Unnamed: 0
# EIF4G3      41.685732   44.687037  89.263148  25.150249   2.946414        NaN
# MACF1       37.198196   45.042544  67.465289  54.071526  13.908363  46.090109
# SMAP2        6.769199   12.429771  89.566912  39.368866   5.216878        NaN
# NFIA        41.357645  108.296960  49.429184  18.010686  34.889126  47.003410
# SRSF11      41.949639   72.257101  48.828780  36.416707   0.000002        NaN
# ...               ...         ...        ...        ...        ...        ...
# TTC3              NaN         NaN        NaN        NaN        NaN        NaN
# DYRK1A            NaN         NaN        NaN        NaN        NaN        NaN
# CHCHD10           NaN         NaN        NaN        NaN        NaN        NaN
# NLGN4X            NaN         NaN        NaN        NaN        NaN        NaN
# HS6ST2            NaN         NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
KMean= KMeans(n_clusters=2)
KMean.fit(corr_df)
label=KMean.predict(corr_df)
silhouette_score(corr_df, label)
# Out:
# 0.39395156174016704

# %%
sns.clustermap(corr_df, cmap ='coolwarm', method='ward')

# %%
"""corr_df_t = corr_df.copy()
corr_df_t["col"] = y_hc
lut = dict(zip(set(y_hc), "rbgy"))
corr_df_t = corr_df_t.replace({"col": lut})
sns.clustermap(corr_df, cmap ='coolwarm', method='ward', row_colors=corr_df_t["col"])
"""
# Out:
# 'corr_df_t = corr_df.copy()\ncorr_df_t["col"] = y_hc\nlut = dict(zip(set(y_hc), "rbgy"))\ncorr_df_t = corr_df_t.replace({"col": lut})\nsns.clustermap(corr_df, cmap =\'coolwarm\', method=\'ward\', row_colors=corr_df_t["col"])\n'

# %%
import matplotlib.pyplot as plt
def optimalK(data, nrefs=3, maxClusters=15):
    """
    Calculates KMeans optimal K using Gap Statistic 
    Params:
        data: ndarry of shape (n_samples, n_features)
        nrefs: number of sample reference datasets to create
        maxClusters: Maximum number of clusters to test for
    Returns: (gaps, optimalK)
    """
    gaps = np.zeros((len(range(1, maxClusters)),))
    resultsdf = pd.DataFrame({'clusterCount':[], 'gap':[]})
    for gap_index, k in enumerate(range(1, maxClusters)):
# Holder for reference dispersion results
        refDisps = np.zeros(nrefs)
# For n references, generate random sample and perform kmeans getting resulting dispersion of each loop
        for i in range(nrefs):
            
            # Create new random reference set
            randomReference = np.random.random_sample(size=data.shape)
            
            # Fit to it
            km = KMeans(k)
            km.fit(randomReference)
            
            refDisp = km.inertia_
            refDisps[i] = refDisp
# Fit cluster to original data and create dispersion
        km = KMeans(k)
        km.fit(data)
        
        origDisp = km.inertia_
# Calculate gap statistic
        gap = np.log(np.mean(refDisps)) - np.log(origDisp)
# Assign this loop's gap statistic to gaps
        gaps[gap_index] = gap
        
        resultsdf = resultsdf.append({'clusterCount':k, 'gap':gap}, ignore_index=True)
    return (gaps.argmax() + 1, resultsdf)


score_g, df = optimalK(corr_df, nrefs=5, maxClusters=10)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K');
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f2ac25d8af0>
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/ubuntu/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/ubuntu/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/ubuntu/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...

# %%
"""import matplotlib.pyplot as plt
def optimalK(data, nrefs=3, maxClusters=15):
    """"""
    Calculates KMeans optimal K using Gap Statistic 
    Params:
        data: ndarry of shape (n_samples, n_features)
        nrefs: number of sample reference datasets to create
        maxClusters: Maximum number of clusters to test for
    Returns: (gaps, optimalK)
    """"""
    gaps = np.zeros((len(range(1, maxClusters)),))
    resultsdf = pd.DataFrame({'clusterCount':[], 'gap':[]})
    for gap_index, k in enumerate(range(1, maxClusters)):
# Holder for reference dispersion results
        refDisps = np.zeros(nrefs)
# For n references, generate random sample and perform kmeans getting resulting dispersion of each loop
        for i in range(nrefs):
            
            # Create new random reference set
            randomReference = np.random.random_sample(size=data.shape)
            
            # Fit to it
            km = KMeans(k)
            km.fit(randomReference)
            
            refDisp = km.inertia_
            refDisps[i] = refDisp
# Fit cluster to original data and create dispersion
        km = KMeans(k)
        km.fit(data)
        
        origDisp = km.inertia_
# Calculate gap statistic
        gap = np.log(np.mean(refDisps)) - np.log(origDisp)
# Assign this loop's gap statistic to gaps
        gaps[gap_index] = gap
        
        resultsdf = resultsdf.append({'clusterCount':k, 'gap':gap}, ignore_index=True)
    return (gaps.argmax() + 1, resultsdf)


score_g, df = optimalK(corr_df, nrefs=5, maxClusters=10)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K');"""
# Out:
# "import matplotlib.pyplot as plt\ndef optimalK(data, nrefs=3, maxClusters=15):\n    \n    Calculates KMeans optimal K using Gap Statistic \n    Params:\n        data: ndarry of shape (n_samples, n_features)\n        nrefs: number of sample reference datasets to create\n        maxClusters: Maximum number of clusters to test for\n    Returns: (gaps, optimalK)\n    \n    gaps = np.zeros((len(range(1, maxClusters)),))\n    resultsdf = pd.DataFrame({'clusterCount':[], 'gap':[]})\n    for gap_index, k in enumerate(range(1, maxClusters)):\n# Holder for reference dispersion results\n        refDisps = np.zeros(nrefs)\n# For n references, generate random sample and perform kmeans getting resulting dispersion of each loop\n        for i in range(nrefs):\n            \n            # Create new random reference set\n            randomReference = np.random.random_sample(size=data.shape)\n            \n            # Fit to it\n            km = KMeans(k)\n            km.fit(randomReference)\n     
# ...

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(model, k=(2,10), timings= True)
visualizer.fit(corr_df)        # Fit data to visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(model, k=(2,10),metric='silhouette', timings= True)
visualizer.fit(corr_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
import scipy.cluster.hierarchy as sch
#Lets create a dendrogram variable linkage is actually the algorithm #itself of hierarchical clustering and then in linkage we have to #specify on which data we apply and engage. This is X dataset
dendrogram = sch.dendrogram(sch.linkage(corr_df, method  = "ward"))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering 
from scipy.stats import combine_pvalues
hc = AgglomerativeClustering(n_clusters = 7, affinity = 'euclidean', linkage ='ward')
# Lets try to fit the hierarchical clustering algorithm  to dataset #X while creating the clusters vector that tells for each customer #which cluster the customer belongs to.
y_hc=hc.fit_predict(corr_df)
y_hc

t_corr_df = corr_df.copy()
t_corr_df["cluster"] = y_hc

all_shared_genes =[]
for x in set(y_hc):
    t_df = t_corr_df[t_corr_df["cluster"] == x]
    print(t_df.index)
    shared_genes = main_df[t_df.index].fillna(0)
    #shared_genes['combined_score'] = shared_genes.apply(lambda x: print(x.values.flatten().tolist()), axis = 1)
    shared_genes["col_integrated"] = shared_genes.apply(lambda x: sum(x.values.flatten().tolist())/len(x.values.flatten().tolist()), axis = 1)
    all_shared_genes.append(shared_genes)
# Out:
# Index(['V3_322', 'V3_S410', 'V2_S914', 'V1_S956', 'V2_S956', 'V4_S956'], dtype='object')
# Index(['V2_167', 'V2_708', 'V1_S408', 'V1_S410', 'V3_S914', 'V5_S956'], dtype='object')
# Index(['V3_559', 'V4_708', 'V3_S408'], dtype='object')
# Index(['V3_167', 'V2_322', 'V2_559', 'V3_708'], dtype='object')
# Index(['V1_167', 'V4_167', 'V1_708', 'V2_S408'], dtype='object')
# Index(['V1_322', 'V2_S410', 'V1_S914', 'V3_S956'], dtype='object')
# Index(['V1_559'], dtype='object')

# %%
final_df = []
genes = []

final_df_full = []

for i,x in enumerate(all_shared_genes):
    genes.append( "MP_" + str(i))

    list1 = list(x.sort_values(by=['col_integrated'], ascending=False).head(100).index)
    final_df_full.append(list(x.sort_values(by=['col_integrated'], ascending=False).index))
    final_df.append(list1)
pd.DataFrame(final_df, index = genes).T.to_csv("t100_genes_per_metaprogram_6_MP.csv", index= None)

# %%
pd.DataFrame(final_df, index = genes).T
# Out:
#           MP_0     MP_1        MP_2      MP_3        MP_4        MP_5  \
# 0       MALAT1   MALAT1      MALAT1    MALAT1      MALAT1  FP236383.3
# 1        RBMS3    NEAT1       NEAT1     PTPRC         FN1  FP671120.4
# 2        AUTS2    LRMDA  FP236383.3     MBNL1      COL3A1      COL1A2
# 3   FP236383.3   PLXDC2      ZBTB20  ARHGAP15      COL1A2      COL1A1
# 4        MBNL1     DPYD         QKI     PRKCH  FP236383.3      COL6A2
# ..         ...      ...         ...       ...         ...         ...
# 95       CNTN4  EPB41L3        DDX5     STAT4        RORA       AGAP1
# 96       MAGI1     STK3      CAMK2D      ACTB       DDX17       SPARC
# 97       CDH13    PTPRJ     ANKRD12    SLC9A9         QKI      PRRC2C
# 98      PDZRN4    ACSL1     TSC22D3   SIPA1L1       LRMDA      TMSB10
# 99       NEGR1   MS4A6A    TP53INP1     KLF12       PDE4B     ANKRD11
#
#           MP_6
# 0       MALAT1
# 1        NEAT1
# 2   FP236383.3
# 3         CD74
# 4         ZEB2
# ..         ...
# ...

# %%
shared_genes.sort_values(by=['col_integrated'], ascending=False).head(100).index
# Out:
# Index(['MALAT1', 'NEAT1', 'FP236383.3', 'CD74', 'ZEB2', 'SAT1', 'LRMDA',
#        'PLXDC2', 'DPYD', 'SLC8A1', 'QKI', 'HLA-DRB1', 'FOS', 'FTH1', 'NAMPT',
#        'ETV6', 'MED13L', 'AKAP13', 'HIF1A', 'LPP', 'DOCK4', 'JMJD1C', 'VMP1',
#        'FMNL2', 'ITPR2', 'UBE2E2', 'DMXL2', 'RNF213', 'SLC9A9', 'FTL', 'PSAP',
#        'MBNL1', 'PDE4B', 'FNDC3B', 'ZFAND3', 'UTRN', 'PARP14', 'KCNMA1',
#        'XIST', 'HNRNPA2B1', 'HLA-DRA', 'ATG7', 'TCF4', 'SIPA1L1', 'GLUL',
#        'BMP2K', 'CHST11', 'FOXN3', 'KLF6', 'PTPRC', 'TNS3', 'B2M', 'ZSWIM6',
#        'STAT1', 'FCHSD2', 'AOAH', 'MACF1', 'FOXP1', 'CTSB', 'GNAQ', 'EXOC4',
#        'VPS13B', 'TBC1D5', 'HLA-B', 'FTX', 'MAML2', 'ASAP1', 'SPIDR', 'SBF2',
#        'TRPS1', 'FP671120.4', 'ELMO1', 'CD163', 'TBC1D22A', 'ARHGAP26',
#        'ARID1B', 'FRMD4B', 'ZBTB20', 'DDX5', 'DUSP1', 'RBM47', 'TCF12',
#        'MEF2A', 'CELF2', 'ACTB', 'WDFY3', 'EXT1', 'VPS13C', 'RUNX1', 'PCNX1',
# ...

# %%
corr_df_t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 corr_df_t
#
# NameError: name 'corr_df_t' is not defined

# %%
corr_df_t["col"]

# %%
lut
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 lut
#
# NameError: name 'lut' is not defined

# %%
corr_df_t = corr_df.copy()
corr_df_t["col"] = y_hc


lut = dict(zip(set(y_hc), "rbgymck"))
corr_df_t = corr_df_t.replace({"col": lut})
sns.clustermap(corr_df, cmap ='coolwarm', method='ward', row_colors=corr_df_t["col"], figsize=(30,30))

# %%
pre_post_labels
# Out:
# ['pre1',
#  'pre1',
#  'pre1',
#  'pre1',
#  'pre2',
#  'pre2',
#  'pre2',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'post1',
#  'post1',
#  'post1',
#  'post2',
#  'post2',
#  'post2',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA']

# %%
lut2 = dict(zip(set(pre_post_labels), "rbmwc"))
lut2
# Out:
# {'post1': 'r', 'pre2': 'b', 'pre1': 'm', 'post2': 'w', 'NA': 'c'}

# %%
corr_df2 = corr_df.copy()
corr_df2.columns = corr_df.columns.str.replace('_', '_S')

# Replace substrings "_" with "_S" in index (row) names
corr_df2.index = corr_df.index.str.replace('_', '_S')

corr_df2.columns = corr_df2.columns.str.replace('_SS', '_S', regex=True)

# Replace substrings "_SS" with "_S" in index (row) names
corr_df2.index = corr_df2.index.str.replace('_SS', '_S', regex=True)
corr_df2 = corr_df2.rename(columns=lambda x: x.replace('_SS', '_S'), 
                           index=lambda x: x.replace('_SS', '_S'))


corr_df2
# Out:
#           V1_S167   V2_S167   V3_S167   V4_S167   V1_S322   V2_S322   V3_S322  \
# V1_S167  1.000000 -0.385795 -0.291802  0.490976  0.601913 -0.390654  0.412011
# V2_S167 -0.385795  1.000000  0.295846 -0.311973 -0.355977  0.667547  0.160028
# V3_S167 -0.291802  0.295846  1.000000 -0.272581 -0.397933  0.887028 -0.091471
# V4_S167  0.490976 -0.311973 -0.272581  1.000000  0.213308 -0.394628  0.642212
# V1_S322  0.601913 -0.355977 -0.397933  0.213308  1.000000 -0.327943 -0.346202
# V2_S322 -0.390654  0.667547  0.887028 -0.394628 -0.327943  1.000000 -0.091703
# V3_S322  0.412011  0.160028 -0.091471  0.642212 -0.346202 -0.091703  1.000000
# V1_S559  0.406030  0.774451 -0.174252  0.499081  0.313331  0.429848  0.476875
# V2_S559 -0.057241 -0.146922  0.942821  0.033779 -0.256157  0.786100  0.086261
# V3_S559  0.489178  0.106459  0.183140  0.391345  0.175018  0.271377  0.579038
# V1_S708  0.742538 -0.080830 -0.187366  0.769120  0.339287 -0.246315  0.586568
# ...

# %%
pre_post_labels


plt.figure(figsize=(10, 10), 
           dpi = 800)
#corr_df_t = corr_df.copy()
corr_df_t["col2"] = pre_post_labels
lut2 = dict(zip(set(pre_post_labels), "rbmwc"))
corr_df_t = corr_df_t.replace({"col2": lut2})

corr_df_t["col3"] = intimal_ups_labels
lut2 = dict(zip(set(intimal_ups_labels), "rb"))
corr_df_t = corr_df_t.replace({"col3": lut2})


corr_df_t["col4"] = op_pre_post_labels
lut2 = dict(zip(set(op_pre_post_labels), "mcy"))
corr_df_t = corr_df_t.replace({"col4": lut2})
plt.figure(dpi = 800) 


sns.clustermap(corr_df2, cmap ='coolwarm', method='ward', row_colors=[corr_df_t["col"],
                                                                     corr_df_t["col3"], corr_df_t['col4']],figsize=(10,10))

# %%
corr_df
# Out:
#            V1_S167   V2_S167   V3_S167   V4_S167   V1_S322   V2_S322  \
# V1_S167   1.000000 -0.385795 -0.291802  0.490976  0.601913 -0.390654
# V2_S167  -0.385795  1.000000  0.295846 -0.311973 -0.355977  0.667547
# V3_S167  -0.291802  0.295846  1.000000 -0.272581 -0.397933  0.887028
# V4_S167   0.490976 -0.311973 -0.272581  1.000000  0.213308 -0.394628
# V1_S322   0.601913 -0.355977 -0.397933  0.213308  1.000000 -0.327943
# V2_S322  -0.390654  0.667547  0.887028 -0.394628 -0.327943  1.000000
# V3_S322   0.412011  0.160028 -0.091471  0.642212 -0.346202 -0.091703
# V1_S559   0.406030  0.774451 -0.174252  0.499081  0.313331  0.429848
# V2_S559  -0.057241 -0.146922  0.942821  0.033779 -0.256157  0.786100
# V3_S559   0.489178  0.106459  0.183140  0.391345  0.175018  0.271377
# V1_S708   0.742538 -0.080830 -0.187366  0.769120  0.339287 -0.246315
# V2_S708  -0.140326  0.932674  0.226450 -0.153404 -0.321000  0.745832
# V3_S708  -0.306153  0.167417  0.938343 -0.306555 -0.337769  0.887264
# ...

# %%
'V2_SS956'.replace('_SS', '_S')
# Out:
# 'V2_S956'

# %%
lut
# Out:
# {0: 'r', 1: 'b', 2: 'g', 3: 'y', 4: 'm', 5: 'c', 6: 'k'}

# %%
###

# %%
pd.DataFrame(final_df_full, index = genes).T
# Out:
#             MP_0      MP_1        MP_2      MP_3        MP_4        MP_5  \
# 0         MALAT1    MALAT1      MALAT1    MALAT1      MALAT1  FP236383.3
# 1          RBMS3     NEAT1       NEAT1     PTPRC         FN1  FP671120.4
# 2          AUTS2     LRMDA  FP236383.3     MBNL1      COL3A1      COL1A2
# 3     FP236383.3    PLXDC2      ZBTB20  ARHGAP15      COL1A2      COL1A1
# 4          MBNL1      DPYD         QKI     PRKCH  FP236383.3      COL6A2
# ...          ...       ...         ...       ...         ...         ...
# 1067       PEX5L     TPD52       NUPR1    MAD1L1       MYO1D    OSMR-AS1
# 1068     SOX2-OT  TP53INP1       MEIS2     INTS1     ANKRD11       WDR70
# 1069        SCD5      KLF6    HSP90AA1   MICALL2       PLCG2      CTNND2
# 1070       UNC5C    PFKFB3     DYNC1H1     PDGFA       PRKCB      SPOCK3
# 1071       DMXL2   FAM214A      HS6ST2    HS6ST2      HS6ST2       DMXL2
#
#             MP_6
# 0         MALAT1
# 1          NEAT1
# 2     FP236383.3
# 3           CD74
# ...

# %%
first_best_samples_H_matrix
# Out:
# ['Sarcoma167GEX/Sarcoma167GEX_KINOMO_nmf_rank_4_H.csv',
#  'Sarcoma322GEX/Sarcoma322GEX_KINOMO_nmf_rank_3_H.csv',
#  'Sarcoma559GEX/Sarcoma559GEX_KINOMO_nmf_rank_3_H.csv',
#  'Sarcoma708GEX/Sarcoma708GEX_KINOMO_nmf_rank_4_H.csv',
#  'SarcomaS408GEX/SarcomaS408GEX_KINOMO_nmf_rank_3_H.csv',
#  'SarcomaS410GEX/SarcomaS410GEX_KINOMO_nmf_rank_3_H.csv',
#  'SarcomaS914GEX/SarcomaS914GEX_KINOMO_nmf_rank_3_H.csv',
#  'SarcomaS956GEX/SarcomaS956GEX_KINOMO_nmf_rank_5_H.csv']

# %%
y_hc
# Out:
# array([4, 1, 3, 4, 5, 3, 0, 6, 3, 2, 4, 1, 3, 2, 1, 4, 2, 1, 5, 0, 5, 0,
#        1, 0, 0, 5, 0, 1])

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(model, k=(2,10), timings= True)
visualizer.fit(corr_df_second)        # Fit data to visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(model, k=(2,10),metric='silhouette', timings= True)
visualizer.fit(corr_df_second)        # Fit the data to the visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
sns.clustermap(corr_df_second, cmap ='coolwarm', method='ward')

# %%
from sklearn.cluster import AgglomerativeClustering 
from scipy.stats import combine_pvalues
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage ='ward')
# Lets try to fit the hierarchical clustering algorithm  to dataset #X while creating the clusters vector that tells for each customer #which cluster the customer belongs to.
y_hc=hc.fit_predict(corr_df_second)
y_hc

t_corr_df = corr_df_second.copy()
t_corr_df["cluster"] = y_hc

all_shared_genes =[]
for x in set(y_hc):
    t_df = t_corr_df[t_corr_df["cluster"] == x]
    print(t_df.index)
    shared_genes = main_df_second[t_df.index].fillna(0)
    #shared_genes['combined_score'] = shared_genes.apply(lambda x: print(x.values.flatten().tolist()), axis = 1)
    shared_genes["col_integrated"] = shared_genes.apply(lambda x: 
                                    sum(x.values.flatten().tolist())/len(x.values.flatten().tolist()), axis = 1)
    all_shared_genes.append(shared_genes)
    
final_df = []
genes = []
for i,x in enumerate(all_shared_genes):
    genes.append( "MP_" + str(i))

    list1 = list(x.sort_values(by=['col_integrated'], ascending=False).head(100).index)
    final_df.append(list1)
pd.DataFrame(final_df, index = genes).T.to_csv("t100_genes_per_metaprogram_second_ranks.csv", index= None)
# Out:
# Index(['V1_167', 'V2_167', 'V2_322', 'V4_322', 'V1_559', 'V4_559', 'V1_708',
#        'V3_708', 'V5_708', 'V1_S408', 'V2_S408', 'V4_S408', 'V5_S408',
#        'V1_S410', 'V2_S410', 'V1_S914', 'V2_S914', 'V2_S956', 'V4_S956',
#        'V5_S956', 'V7_S956', 'V8_S956'],
#       dtype='object')
# Index(['V3_167', 'V4_167', 'V3_322', 'V2_559', 'V5_559', 'V6_559', 'V4_708',
#        'V6_708', 'V3_S408', 'V4_S410', 'V4_S914', 'V3_S956'],
#       dtype='object')
# Index(['V5_167', 'V1_322', 'V5_322', 'V3_559', 'V2_708', 'V3_S410', 'V5_S410',
#        'V3_S914', 'V5_S914', 'V1_S956', 'V6_S956'],
#       dtype='object')

# %%
corr_df_t = corr_df_second.copy()
corr_df_t["col"] = y_hc
lut = dict(zip(set(y_hc), "rbgym"))
corr_df_t = corr_df_t.replace({"col": lut})
sns.clustermap(corr_df_second, cmap ='coolwarm', method='ward', row_colors=corr_df_t["col"])

# %%
#corr_df_t = corr_df.copy()
corr_df_t["col2"] = pre_post_labels_second
lut2 = dict(zip(set(pre_post_labels_second), "rbgym"))
corr_df_t = corr_df_t.replace({"col2": lut2})
sns.clustermap(corr_df_second, cmap ='coolwarm', method='ward', row_colors=[corr_df_t["col"], corr_df_t["col2"]])
